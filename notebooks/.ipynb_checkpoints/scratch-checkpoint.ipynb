# %%
import os
import urllib
import anndata

# %%
# %%time
# url = "https://zenodo.org/record/10044268/files/SrivatsanTrapnell2020_sciplex2.h5ad?download=1"
output_path = "/scratch/data/norman_2019.h5ad"

# if not os.path.exists(output_path):
#     urllib.request.urlretrieve(url, output_path)
#     print(f"Downloaded to {output_path}")
# else:
#     print(f"File already exists: {output_path}")

adata = anndata.read_h5ad(output_path)
# Out:
# CPU times: user 27.7 s, sys: 2.26 s, total: 29.9 s
# Wall time: 30.2 s

# %%
# adata[adata.obs.perturbation_name == "control"].obs["total_count"]
adata.n_obs
# Out:
# 111255

# %%
from scanpy import settings
settings.datasetdir = "/data"
settings.datasetdir
# Out:
# PosixPath('/data')
